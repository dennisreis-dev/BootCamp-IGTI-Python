# %% [markdown]
# <a href="https://colab.research.google.com/github/dennisreis-dev/IGTI-Python/blob/master/trabalhando_com_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Programação Estruturada x Orientação a Objetos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Reutilização de códigos através de módulos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Arquivo com extensão .py que contém códigos;
# 2.   Pode definir funções, classes ou variáveis;
# 3.   Utilizando o "import" para importar os módulos;
# 4.   Diretório de pesquisa ("PYTHONPATH") onde os módulos estão localizados;
# 5.   O módulo é carregado apenas 1 vez (não importa as vezes que o "import" é chamado.)

# %% [markdown]
# **import < nome_do_modulo >**

# %%
#acessando o local onde os múdulos estão armazenados
import sys
print(sys.path)
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']

# %%
#utilizando módulos em python
import math  #módulo que contém as funções matemáticas

print("O valor de pi é: ",math.pi)                #valor de pi
print("O seno de 45° é: ",math.sin(math.pi/4))    #seno de pi/4
print("O cosseno de 180° é: ",math.cos(math.pi))      #cosseno de pi
# Out:
# O valor de pi é:  3.141592653589793
# O seno de 45° é:  0.7071067811865475
# O cosseno de 180° é:  -1.0

# %% [markdown]
# **import < modulo_1 >[, < modulo_2 > ...]**

# %%
import math, datetime 

print(datetime.datetime.now())
# Out:
# 2020-07-12 16:11:26.415219

# %%
#utilizando módulos "build-in" em python
print("Módulo string: ", str(124))
print("Módulo float: ",float(123/12))
# Out:
# Módulo string:  124
# Módulo float:  10.25

# %%
import platform  #módulo utilizado para monitorar a plataforma (S.O) que estamos utilizando

x = platform
plataforma=x.system()
print(plataforma)
print(x.python_version())
print(x.processor())
# Out:
# Linux
# 3.6.9
# x86_64

# %%
#utilizando a minha própria função
import meu_modulo

meu_modulo.print_boas_vindas("Tulio")
# Out:
# Olá, Tulio. Tudo bem com você?

# %% [markdown]
# **O módulo só é carregado uma vez**

# %%
#mostrando que o carregamento só ocorre uma vez
import modulo_teste
# Out:
# a = [100, 200, 300]

# %%
import modulo_teste

# %%
#forçando o novo carregamento
import importlib
importlib.reload(modulo_teste)
# Out:
# a = [100, 200, 300]
# <module 'modulo_teste' from '/content/modulo_teste.py'>

# %% [markdown]
# **O from módulo import atributo**

# %% [markdown]
# 1.   Importamos apenas o que interessa;
# 2.   Não importa todo mundo;

# %%
#realizando um import da maneira "mais correta"
from math import factorial
numero=5
print("O fatorial de {} é {}".format(numero,factorial(numero)))
# Out:
# O fatorial de 5 é 120

# %% [markdown]
# from < nome_do_modulo > import *

# %%
#utilizando o * para importar tudo
from math import *
numero=6
print("O fatorial de {} é {}".format(numero,factorial(numero)))
# Out:
# O fatorial de 6 é 720

# %% [markdown]
# **from < nome_do_modulo > import < nome > as < nome_alternativo >**

# %%
from math import factorial as fatorial
numero=5
print("O fatorial de {} é {}".format(numero,fatorial(numero)))
# Out:
# O fatorial de 5 é 120

# %% [markdown]
# **import < nome_do_modulo > as < nome_alternativo >**

# %%
import meu_modulo as modulo_1
modulo_1.print_boas_vindas("Tulio")
# Out:
# Olá, Tulio. Tudo bem com você?

# %% [markdown]
# **A tabela de lista de nomes em Python**

# %%
#mostrando a tabela de nomes existente 
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'math',
#  'quit']

# %%
import math

# %%
#verificando os nomes definidos pelo módulo
import math

conteudo = dir(math)
print(conteudo)
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %% [markdown]
# **Instalando novos módulos no Google Colab**

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp36-none-any.whl size=4032 sha256=e5dae53dd23a8a6d33ec7ae6b065568dca05f43cb44ce9628581836f9579f93c
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle import Turtle #importando o módulo

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'Turtle',
#  '_',
#  '_1',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'conteudo',
#  'exit',
#  'get_ipython',
#  'math',
#  'quit']

# %%
t=Turtle
t.initializeTurtle()
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="225.0" x2="376.15707623129435" y2="217.48235501239319" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="376.15707623129435" y1="217.48235501239319" x2="361.8176653225182" y2="237.96115611961798" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="361.8176653225182" y1="237.96115611961798" x2="377.03670104773624" y2="257.7949896268989" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="377.03670104773624" y1="257.7949896268989" x2="400.52901656738396" y2="249.24448604375718" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(250.0,400.52901656738396,249.24448604375718) translate(400.52901656738396, 249.24448604375718)">
# ...

# %% [markdown]
# # **Pacotes (packages) em Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pacotes.modulo_1, pacotes.modulo_2

pacotes.modulo_1.facao_isso()
pacotes.modulo_2.faca_isso_tambem()
# Out:
# [modulo_1] faca_isso()
# [modulo_2] faca_isso_tambem()

# %%
from pacotes.modulo_1 import facao_isso
facao_isso()
# Out:
# [modulo_1] faca_isso()

# %%
from pacotes.modulo_2 import FacaIssoTambem as faca

objeto=faca()
objeto

# %%
from pacotes import *

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'Turtle',
#  '_',
#  '_1',
#  '_11',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'faca',
#  'facao_isso',
#  'get_ipython',
#  'math',
#  'modulo_1',
#  'modulo_2',
#  'objeto',
#  'pacotes',
#  'quit',
#  't']

# %% [markdown]
# # **Construtores**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#criando uma classe Carro
class Carro:
  def __init__(self,numero_portas,preco): #__init__ é um construtor da classe
    self.numero_portas=numero_portas
    self.preco=preco
    print("Objeto carro instanciado com sucesso.")
  def get_numero_portas(self):
    return self.numero_portas


carro_1=Carro(4,50000)
# Out:
# Objeto carro instanciado com sucesso.

# %%
portas_carro_1=carro_1.get_numero_portas()
print("Meu carro possui %d portas." %portas_carro_1)
# Out:
# Meu carro possui 4 portas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
carro_2=Carro(2,80000)
portas_carro_2=carro_2.get_numero_portas()
print("Meu carro possui %d portas." %portas_carro_2)
# Out:
# Objeto carro instanciado com sucesso.
# Meu carro possui 2 portas.

# %%
print("Endereço memória carro_1: ",hex(id(carro_1)))
print("Endereço memória carro_2: ",hex(id(carro_2)))
# Out:
# Endereço memória carro_1:  0x7f2b11e584e0
# Endereço memória carro_2:  0x7f2b11e438d0

# %%
#podemos ter mais de um construtor para uma classe
string=str(6)
print(string)
inteiro=int("6")
print(inteiro)
float_1=float("6")  #construtor recebendo uma string
print(float_1)
float_2=float(inteiro)  #construtor recebendo um inteiro
print(float_2)
lista=list("a b c")
print(lista)
# Out:
# 6
# 6
# 6.0
# 6.0
# ['a', ' ', 'b', ' ', 'c']

# %% [markdown]
# **Métodos acessores e modificadores**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# importando o modulo array 
import array  as ar
     
#inicializando o array 
meu_array = ar.array('i', [5, 1, 3, 4, 2, 2, 7]) 

#print do array
print(meu_array)
  
# acessaando o indice do valor igual a 2
print(meu_array.index(2)) 
  
# acessando a quantida de de valores 2 existentes 
print(meu_array.count(2))
# Out:
# array('i', [5, 1, 3, 4, 2, 2, 7])
# 4
# 2

# %%
#criando uma classe Carro
class Carro:
  def __init__(self,numero_portas,preco):
    self.numero_portas=numero_portas
    self.preco=preco
    print("Objeto carro instanciado com sucesso.")
  def get_numero_portas(self):
    return self.numero_portas
  def set_numero_portas(self,novo_numero_portas):
    self.numero_portas=novo_numero_portas


carro_3=Carro(4,50000)
print("Numero de portas antes: ", carro_3.get_numero_portas())  #método get - Não modifica o estado do objeto
carro_3.set_numero_portas(2) #modifica o estado do objeto
print("Novo número de portas: ", carro_3.get_numero_portas())
# Out:
# Objeto carro instanciado com sucesso.
# Numero de portas antes:  4
# Novo número de portas:  2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#criando uma classe Carro
class Carro:
  def __init__(self,numero_portas,preco):
    self.numero_portas=numero_portas
    self.preco=preco
    print("Objeto carro instanciado com sucesso.")
  def get_numero_portas(self):
    return self.numero_portas
  def set_numero_portas(self,novo_numero_portas):
    self.numero_portas=novo_numero_portas


carro_3=Carro(4,50000)
print("Numero de portas antes: ", carro_3.get_numero_portas())  #método get - Não modifica o estado do objeto
carro_3.set_numero_portas(2) #modifica o estado do objeto

#cria a referencia ao objeto carro
carro_4=carro_3
print("Número de portas carro_4: ", carro_4.get_numero_portas())

#modificando o número de portas do carrro_4
carro_4.set_numero_portas(3)
print("Novo número de portas do carro_4: ", carro_4.get_numero_portas())

#numero de portas do carro_3
print("Número de portas carro_3: ", carro_3.get_numero_portas())
# Out:
# Objeto carro instanciado com sucesso.
# Numero de portas antes:  4
# Número de portas carro_4:  2
# Novo número de portas do carro_4:  3
# Número de portas carro_3:  3

# %% [markdown]
# **Classes imutáveis**

# %%
#classes que não possuem métodos mutáveis - int, float, string
string="Estou estudando Python"
print(id(string))
string=string+" no IGTI"
print(id(string))
print(string)
# Out:
# 139822960622016
# 139822953634752
# Estou estudando Python no IGTI

# %% [markdown]
# # **Trabalhando com arquivos XML**

# %% [markdown]
# Extensible Markup Language (XML)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# Fonte: DBA PRO - https://dba-pro.com/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <?xml version="1.0"  encoding = "UTF-8" standalone = "no"?>
# <data>
#     <items>
#         <item name="item1">Arroz</item>
#         <item name="item2">Feijão</item>
#         <item name="item3">Batata</item>
#         <item name="item4">Molho de Tomate</item>
#         <item name="item5">Macarrão</item>
#     </items>
# </data>
# ```

# %%
from xml.dom import minidom  #importa o modulo para leitura de arquivos xml
nome_do_arquivo_xml='arquivo_xml.xml'  #nome do arquivo a ser importado
documento_xml=minidom.parse(nome_do_arquivo_xml)    #instancia o objeto

# %%
documento_xml

# %%
#nós presentes no documento
nos = documento_xml.documentElement
print(nos.tagName)
# Out:
# data

# %%
#extraindo elementos de um arquivo xml
#cada elemento em um arquivo xml tem um nome
lista_de_compras=documento_xml.getElementsByTagName("item")
type(lista_de_compras)
# Out:
# xml.dom.minicompat.NodeList

# %%
lista_de_compras[0]
# Out:
# <DOM Element: item at 0x7f2b116cf508>

# %%
#acessando os atributos de um arquivo
for item in lista_de_compras:
  print(item.attributes['name'].value)
# Out:
# item1
# item2
# item3
# item4
# item5

# %%
#acessando os elementos de um arquivo
for item in lista_de_compras:
  print(item.firstChild.data)
# Out:
# Arroz
# Feijão
# Batata
# Molho de Tomate
# Macarrão
